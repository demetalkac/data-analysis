# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Effective Data Visualization Project</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# ## CODING TASK #1. PLOT PIE CHART USING MATPLOTLIB

# %% [markdown]
# - **The plot method on Pandas Series and DataFrames is just a simple wrapper around plt.plot():**
# - **Define a Pandas Dataframe with all crypto allocation in a given portfolio**
# - **Note that total sum = 100%**
# - **Use matplotlib to plot a pie chart**

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
crypto_df = pd.DataFrame(data = {'allocation %':[20, 55, 5, 17, 3]}, index = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
crypto_df
# Out:
#      allocation %
# BTC            20
# ETH            55
# LTC             5
# XRP            17
# ADA             3

# %%
allocation = crypto_df["allocation %"]
crypto = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA']

plt.figure(figsize=(10,10), facecolor="thistle")

plt.pie(allocation, labels=crypto, autopct='%1.1f%%',
        startangle=90, 
        colors=['cadetblue', 'orange', 'grey', 'darkviolet', 'blue']);

plt.legend(title = "Crypto")

plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Assume that you became bullish on XRP and decided to allocate 60% of your assets in it. You also decided to equally divide the rest of your assets in other coins (BTC, LTC, ADA, and ETH). Change the allocations and plot the pie chart.**
# - **Use 'explode' to increase the separation between XRP and the rest of the portfolio (External Research is Required)**

# %%
crypto_df["allocation %"] = [10, 10, 10, 60, 10]
crypto_df
# Out:
#      allocation %
# BTC            10
# ETH            10
# LTC            10
# XRP            60
# ADA            10

# %%
allocation = crypto_df["allocation %"]
crypto = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA']

plt.figure(figsize=(15,10), facecolor="lightseagreen")

plt.pie(allocation, labels=crypto, 
        autopct='%1.1f%%',
        startangle=90,
        colors=['skyblue', 'orange', 'grey', 'darkviolet', 'blue'])

plt.legend(title="Coins")

plt.show()

# %%
explode = (0, 0, 0, 0.1, 0)

allocation = crypto_df["allocation %"]
crypto = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA']

plt.figure(figsize=(15,10), facecolor="aqua")

plt.pie(allocation, labels=crypto,
        explode=explode,
        autopct='%1.1f%%',
        startangle=90,
        colors=['blue', 'orange', 'green', 'red', 'purple'])

plt.legend(title="Coins")

plt.show()

# %% [markdown]
# ## CODING TASK #2. PLOT SINGLE & MULTIPLE LINE PLOTS USING MATPLOTLIB
# - **Use Pandas read_csv to read crypto_daily_prices (BTC, ETH, and LTC)**
# - **Use matplotlib on the Pandas DataFrame to plot the data**

# %%
investments = pd.read_csv('crypto_daily_prices.csv')
investments
# Out:
#            Date           BTC          ETH       ADA
# 0     9/17/2014    457.334015          NaN       NaN
# 1     9/18/2014    424.440002          NaN       NaN
# 2     9/19/2014    394.795990          NaN       NaN
# 3     9/20/2014    408.903992          NaN       NaN
# 4     9/21/2014    398.821014          NaN       NaN
# ...         ...           ...          ...       ...
# 2828  6/15/2022  22572.839840  1233.206421  0.533296
# 2829  6/16/2022  20381.650390  1067.730713  0.475022
# 2830  6/17/2022  20471.482420  1086.519287  0.487392
# 2831  6/18/2022  19017.642580   993.636780  0.456182
# 2832  6/19/2022  19488.886720  1040.510254  0.464109
#
# [2833 rows x 4 columns]

# %%
plt.style.use("seaborn-v0_8-darkgrid")

# %%
investments['Date'] = pd.to_datetime(investments['Date'])

# %%
plt.figure(figsize=(10,5), facecolor="orange")

ax = plt.axes()
ax.set_facecolor("cadetblue")

plt.plot(investments["Date"], investments["BTC"], lw=2, label="BTC", color="darkblue")
plt.plot(investments["Date"], investments["ETH"], lw=2, label="ETH", color="black")
plt.plot(investments["Date"], investments["ADA"], lw=2, label="ADA", color="darkred")


plt.title("BTC - ETH - ADA", fontsize=18, fontweight="bold")
plt.xlabel("DATE", fontsize=18, fontweight="bold")
plt.ylabel("PRICE", fontsize=18, fontweight="bold")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Use subplots attribute to plot separate figures for BTC, ETH, and ADA**

# %%
fig, ax = plt.subplots(3,1, figsize=(10,10), facecolor="orange", )


ax[0].plot(investments["Date"], investments["BTC"], lw=1.5, label="BTC", color="darkblue")
ax[0].set_xlabel("YEAR", fontsize=12, fontweight="bold")
ax[0].set_ylabel("PRICE ($)", fontsize=12, fontweight="bold")
ax[0].set_title("BTC", fontsize=12, fontweight="bold")
ax[0].set_facecolor("darkgrey")

ax[1].plot(investments["Date"], investments["ETH"], lw=1.5, label="ETH", color="black")
ax[1].set_xlabel("YEAR", fontsize=12, fontweight="bold")
ax[1].set_ylabel("PRICE ($)", fontsize=12, fontweight="bold")
ax[1].set_title("ETH", fontsize=12, fontweight="bold")
ax[1].set_facecolor("darkgrey")

ax[2].plot(investments["Date"], investments["ADA"], lw=1.5, label="ADA", color="darkred")
ax[2].set_xlabel("YEAR", fontsize=12, fontweight="bold")
ax[2].set_ylabel("PRICE, ($)", fontsize=12, fontweight="bold")
ax[2].set_title("ADA", fontsize=12, fontweight="bold")
ax[2].set_facecolor("darkgrey")

    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CODING TASK #3. PLOT SCATTERPLOTS USING MATPLOTLIB
# - **Read daily return data using pandas**
# - **Plot Daily returns of BTC vs. ETH**

# %%
daily_returns = pd.read_csv('crypto_daily_returns.csv')
daily_returns
# Out:
#            Date       BTC        ETH        ADA
# 0     9/17/2014  0.000000   0.000000   0.000000
# 1     9/18/2014 -7.192558        NaN        NaN
# 2     9/19/2014 -6.984264        NaN        NaN
# 3     9/20/2014  3.573492        NaN        NaN
# 4     9/21/2014 -2.465854        NaN        NaN
# ...         ...       ...        ...        ...
# 2828  6/15/2022  1.648355   1.778018  10.097317
# 2829  6/16/2022 -9.707194 -13.418330 -10.927140
# 2830  6/17/2022  0.440750   1.759673   2.604094
# 2831  6/18/2022 -7.101781  -8.548629  -6.403471
# 2832  6/19/2022  2.477931   4.717365   1.737703
#
# [2833 rows x 4 columns]

# %%
fig, ax = plt.subplots(1,2, figsize=(11,5), facecolor="orange", )


ax[0].plot(investments["Date"], investments["BTC"], lw=1.5, label="BTC", color="darkblue")
ax[0].set_xlabel("YEAR", fontsize=12, fontweight="bold")
ax[0].set_ylabel("PRICE ($)", fontsize=12, fontweight="bold")
ax[0].set_title("BTC", fontsize=12, fontweight="bold")
ax[0].set_facecolor("darkgrey")

ax[1].plot(investments["Date"], investments["ETH"], lw=1.5, label="ETH", color="black")
ax[1].set_xlabel("YEAR", fontsize=12, fontweight="bold")
ax[1].set_ylabel("PRICE ($)", fontsize=12, fontweight="bold")
ax[1].set_title("ETH", fontsize=12, fontweight="bold")
ax[1].set_facecolor("darkgrey")

plt.tight_layout()
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #3:**
# - **Plot the daily returns of BTC vs. ADA, choose your favourite color!**

# %%
fig, ax = plt.subplots(1,2, figsize=(11,5), facecolor="orange", )


ax[0].plot(investments["Date"], investments["BTC"], lw=1.5, label="BTC", color="darkblue")
ax[0].set_xlabel("YEAR", fontsize=12, fontweight="bold")
ax[0].set_ylabel("PRICE ($)", fontsize=12, fontweight="bold")
ax[0].set_title("BTC", fontsize=12, fontweight="bold")
ax[0].set_facecolor("darkgrey")

ax[1].plot(investments["Date"], investments["ADA"], lw=1.5, label="ADA", color="darkred")
ax[1].set_xlabel("YEAR", fontsize=12, fontweight="bold")
ax[1].set_ylabel("PRICE ($)", fontsize=12, fontweight="bold")
ax[1].set_title("ADA", fontsize=12, fontweight="bold")
ax[1].set_facecolor("darkgrey")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## CODING TASK #4. PLOT HISTOGRAMS USING MATPLOTLIB
# - **A histogram represents data using bars with various heights**
# - **Each bar groups numbers into specific ranges**
# - **Taller bars show that more data falls within that specific range**
# - **Plot the histogram of the returns**

# %%
daily_returns = pd.read_csv('crypto_daily_returns.csv')
daily_returns
# Out:
#            Date       BTC        ETH        ADA
# 0     9/17/2014  0.000000   0.000000   0.000000
# 1     9/18/2014 -7.192558        NaN        NaN
# 2     9/19/2014 -6.984264        NaN        NaN
# 3     9/20/2014  3.573492        NaN        NaN
# 4     9/21/2014 -2.465854        NaN        NaN
# ...         ...       ...        ...        ...
# 2828  6/15/2022  1.648355   1.778018  10.097317
# 2829  6/16/2022 -9.707194 -13.418330 -10.927140
# 2830  6/17/2022  0.440750   1.759673   2.604094
# 2831  6/18/2022 -7.101781  -8.548629  -6.403471
# 2832  6/19/2022  2.477931   4.717365   1.737703
#
# [2833 rows x 4 columns]

# %%
mu = round(daily_returns['BTC'].mean(), 2) # mean of distribution
sigma = round(daily_returns['BTC'].std(), 2) # standard deviation of distribution
 
num_bins = 40

# %%
plt.figure(figsize=(15, 10), facecolor="#B0E0E6")

cryptos = daily_returns.columns[1:] 

for i, crypto in enumerate(cryptos, 1):
    mu_crypto = round(daily_returns[crypto].mean(), 2)
    sigma_crypto = round(daily_returns[crypto].std(), 2)
    
    plt.subplot(2, 2, i)

    n, bins, patches = plt.hist(daily_returns[crypto], num_bins, density=True, alpha=0.6, color='blue')
   
    y = ((1 / (np.sqrt(2 * np.pi) * sigma_crypto)) * np.exp(-0.5 * (1 / sigma_crypto * (bins - mu_crypto))**2))
    plt.plot(bins, y, '--', color='black')
    
    plt.xlabel(f'{crypto} Daily Returns (%)')
    plt.ylabel('Probability Density')
    plt.title(f'Histogram of {crypto} Daily Returns\nMean = {mu_crypto}, Standard Deviation = {sigma_crypto}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #4:**
# - **Plot the histogram for BTC and ETH returns using 60 bins. Display all histograms on the same figure**

# %%
plt.figure(figsize=(15, 10))

cryptos = daily_returns.columns[1:3] 

for i, crypto in enumerate(cryptos, 1):
    mu_crypto = round(daily_returns[crypto].mean(), 2)
    sigma_crypto = round(daily_returns[crypto].std(), 2)
    
    plt.subplot(2, 2, i)

    n, bins, patches = plt.hist(daily_returns[crypto], 60, density=True, alpha=0.6, color='blue')
   
    y = ((1 / (np.sqrt(2 * np.pi) * sigma_crypto)) * np.exp(-0.5 * (1 / sigma_crypto * (bins - mu_crypto))**2))
    plt.plot(bins, y, '--', color='black')
    
    plt.xlabel(f'{crypto} Daily Returns (%)')
    plt.ylabel('Probability Density')
    plt.title(f'Histogram of {crypto} Daily Returns\nMean = {mu_crypto}, Standard Deviation = {sigma_crypto}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## CODING TASK #5. PLOT SCATTERPLOT & COUNTPLOT USING SEABORN
# - **Seaborn is a visualization library that sits on top of matplotlib**
# - **Seaborn offers enhanced features compared to matplotlib**
# - **https://seaborn.pydata.org/examples/index.html*/*
# - **Check out the head of the dataframe**
# - **Check out the tail of the dataframe**
# - **Plot scatter plot between mean area and mean smoothness**
# - **Let's print out countplot to know how many samples belong to class #0 and #1**

# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import seaborn as sns # Statistical data visualization

# %%
# Import Cancer data 
cancer = pd.read_csv('cancer.csv')

# %%
cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
cancer.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
# ...

# %%
plt.figure(figsize=(10,5), facecolor="cyan")

sns.scatterplot(data=cancer, x="mean smoothness", y="mean area", hue="target", palette="plasma", style="target")

plt.title("MEAN SMOOTHNESS - MEAN AREA", fontsize=10, fontweight="bold")
plt.xlabel("MEAN SMOOTHNESS", fontsize=10, fontweight="bold")
plt.ylabel("MEAN AREA", fontsize=10, fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Plot the scatterplot between the mean radius and mean area. Comment on the plot**

# %%
plt.figure(figsize=(10,6), facecolor="cyan")

sns.scatterplot(data=cancer, x="mean radius", y="mean area", hue="target", palette="plasma", style="target")

plt.title("MEAN RADIUS - MEAN AREA", fontsize=10, fontweight="bold")
plt.xlabel("MEAN RADIUS", fontsize=10, fontweight="bold")
plt.ylabel("MEAN AREA", fontsize=10, fontweight="bold")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,5), facecolor="orange")

sns.countplot(data=cancer, x="target", palette="plasma")

plt.title("BENIGN - MALIGN", fontsize=10, fontweight="bold")
plt.xlabel("TARGET", fontsize=10, fontweight="bold")
plt.ylabel("COUNT", fontsize=10, fontweight="bold")


plt.tight_layout()
plt.show()

# %% [markdown]
# ## CODING TASK #6. PLOT PAIRPLOT, DISPLOT, AND HEATMAPS/CORRELATIONS USING SEABORN

# %% [markdown]
# - **Plot the pairplot**
# - **Strong correlation between the mean radius and mean perimeter, mean area and mean primeter**
# - **plot the distplot**
# - **Displot combines matplotlib histogram function with kdeplot() (Kernel density estimate)**
# - **KDE is used to plot the Probability Density of a continuous variable.**

# %%
x = sns.pairplot(cancer, diag_kind="hist", hue="target", vars = ['mean radius', 'mean perimeter', 'mean area'])

x = x.map_upper(sns.scatterplot)
x = x.map_diag(sns.histplot, edgecolor="black", kde=True)
x = x.map_lower(sns.kdeplot)

plt.suptitle('Pairplot of Mean Radius - Mean Perimeter - Mean Area', y=1.05)

plt.show()

# %%
corr_matrix = cancer[["mean radius", "mean perimeter"]].corr()

plt.figure(figsize=(10,5), facecolor="cyan")

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths="0.5")

plt.title("Correlation Matrix", fontsize=16)
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Plot two separate distplot for each target class #0 and target class #1**

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT

# %% [markdown]
# - In this project, we will visualize stock prices using Seaborn and Matplotlib. 4 Stocks are considered including JP Morgan Chase (JP), Procter and Gamble (P&G) (PG), Apple (AAPL) and United Airlines (UAL).
# - Using the stock_daily_prices.csv and stocks_daily_returns.csv dataset included in the course/workshop package, please do the following:
#     - Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.

# %% [markdown]
# - Import both datasets using Pandas.

# %%
stock_daily_prices = pd.read_csv('stocks_daily_prices.csv')
stock_daily_returns = pd.read_csv('stocks_daily_returns.csv')

# %%
stock_daily_prices.head(3)
# Out:
#        Date      AAPL        JPM         PG        UAL
# 0  1/2/2008  5.949703  29.448614  47.058838  29.915234
# 1  1/3/2008  5.952452  29.246094  47.058838  29.690800
# 2  1/4/2008  5.498071  28.582682  46.870098  31.000002

# %%
stock_daily_returns.head(3)
# Out:
#        Date      AAPL       JPM        PG       UAL
# 0  1/2/2008  0.000000  0.000000  0.000000  0.000000
# 1  1/3/2008  0.046203 -0.687708  0.000000 -0.750233
# 2  1/4/2008 -7.633517 -2.268378 -0.401072  4.409454

# %%
stock_daily_prices['Date'] = pd.to_datetime(stock_daily_prices['Date'])
stock_daily_returns['Date'] = pd.to_datetime(stock_daily_returns['Date'])

# %% [markdown]
# - Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure

# %%
plt.figure(figsize=(15,10), facecolor="lightsalmon")

ax = plt.axes()
ax.set_facecolor("cadetblue")

plt.plot(stock_daily_prices['Date'], stock_daily_prices["AAPL"], color="yellow")
plt.plot(stock_daily_prices['Date'], stock_daily_prices["JPM"], color="red")
plt.plot(stock_daily_prices['Date'], stock_daily_prices["PG"], color="black")
plt.plot(stock_daily_prices['Date'], stock_daily_prices["UAL"], color="whitesmoke")

plt.title("AAPLC - JPM - PG - UAL", fontsize=18, fontweight="bold")
plt.xlabel("DATE", fontsize=18, fontweight="bold")
plt.ylabel("PRICE", fontsize=18, fontweight="bold")

plt.legend(stock_daily_prices[["AAPL", "JPM", "PG", "UAL"]])
plt.tight_layout()
plt.show()

# %% [markdown]
# - Using Matplotlib, plot 4 stocks daily prices on multiple subplots

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,8), facecolor="lightblue")


ax[0][0].plot(stock_daily_prices['Date'], stock_daily_prices["AAPL"], color="green")
ax[0][0].set_facecolor("lightgrey")
ax[0][0].set_xlabel("DATE", fontsize=12)
ax[0][0].set_ylabel("PRICE", fontsize=12)
ax[0][0].set_title("APPLE", fontsize=14, fontweight="bold")

ax[0][1].plot(stock_daily_prices['Date'], stock_daily_prices["JPM"], color="midnightblue")
ax[0][1].set_facecolor("lightgrey")
ax[0][1].set_xlabel("DATE", fontsize=12)
ax[0][1].set_ylabel("PRICE", fontsize=12)
ax[0][1].set_title("J.P. MORGAN", fontsize=14, fontweight="bold")

ax[1][0].plot(stock_daily_prices['Date'], stock_daily_prices["PG"], color="darkmagenta")
ax[1][0].set_facecolor("lightgrey")
ax[1][0].set_xlabel("DATE", fontsize=12)
ax[1][0].set_ylabel("PRICE", fontsize=12)
ax[1][0].set_title("PROCTER and GAMBLE", fontsize=14, fontweight="bold")

ax[1][1].plot(stock_daily_prices['Date'], stock_daily_prices["UAL"], color="red")
ax[1][1].set_facecolor("lightgrey")
ax[1][1].set_xlabel("DATE", fontsize=12)
ax[1][1].set_ylabel("PRICE", fontsize=12)
ax[1][1].set_title("UNITED AIRLINES", fontsize=14, fontweight="bold")


ax[0][0].spines['left'].set_color('black')
ax[0][0].spines['left'].set_linewidth(1.5)
ax[0][0].spines['right'].set_color('black')
ax[0][0].spines['right'].set_linewidth(1.5)
ax[0][0].spines['top'].set_color('black')
ax[0][0].spines['top'].set_linewidth(1.5)
ax[0][0].spines['bottom'].set_color('black')
ax[0][0].spines['bottom'].set_linewidth(1.5)

ax[0][1].spines['left'].set_color('black')
ax[0][1].spines['left'].set_linewidth(1.5)
ax[0][1].spines['right'].set_color('black')
ax[0][1].spines['right'].set_linewidth(1.5)
ax[0][1].spines['top'].set_color('black')
ax[0][1].spines['top'].set_linewidth(1.5)
ax[0][1].spines['bottom'].set_color('black')
ax[0][1].spines['bottom'].set_linewidth(1.5)

ax[1][0].spines['left'].set_color('black')
ax[1][0].spines['left'].set_linewidth(1.5)
ax[1][0].spines['right'].set_color('black')
ax[1][0].spines['right'].set_linewidth(1.5)
ax[1][0].spines['top'].set_color('black')
ax[1][0].spines['top'].set_linewidth(1.5)
ax[1][0].spines['bottom'].set_color('black')
ax[1][0].spines['bottom'].set_linewidth(1.5)

ax[1][1].spines['left'].set_color('black')
ax[1][1].spines['left'].set_linewidth(1.5)
ax[1][1].spines['right'].set_color('black')
ax[1][1].spines['right'].set_linewidth(1.5)
ax[1][1].spines['top'].set_color('black')
ax[1][1].spines['top'].set_linewidth(1.5)
ax[1][1].spines['bottom'].set_color('black')
ax[1][1].spines['bottom'].set_linewidth(1.5)


plt.tight_layout()
plt.show()

# %% [markdown]
# - Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row)

# %%
fig, ax = plt.subplots(1, 4, figsize=(16,4), facecolor="lightblue")


ax[0].plot(stock_daily_prices['Date'], stock_daily_prices["AAPL"], color="sienna")
ax[0].set_facecolor("lightgrey")
ax[0].set_xlabel("DATE", fontsize=12)
ax[0].set_ylabel("PRICE", fontsize=12)
ax[0].set_title("APPLE", fontsize=14, fontweight="bold")

ax[1].plot(stock_daily_prices['Date'], stock_daily_prices["JPM"], color="midnightblue")
ax[1].set_facecolor("lightgrey")
ax[1].set_xlabel("DATE", fontsize=12)
ax[1].set_ylabel("PRICE", fontsize=12)
ax[1].set_title("J.P. MORGAN", fontsize=14, fontweight="bold")

ax[2].plot(stock_daily_prices['Date'], stock_daily_prices["PG"], color="darkmagenta")
ax[2].set_facecolor("lightgrey")
ax[2].set_xlabel("DATE", fontsize=12)
ax[2].set_ylabel("PRICE", fontsize=12)
ax[2].set_title("PROCTER and GAMBLE", fontsize=14, fontweight="bold")

ax[3].plot(stock_daily_prices['Date'], stock_daily_prices["UAL"], color="darkolivegreen")
ax[3].set_facecolor("lightgrey")
ax[3].set_xlabel("DATE", fontsize=12)
ax[3].set_ylabel("PRICE", fontsize=12)
ax[3].set_title("UNITED AIRLINES", fontsize=14, fontweight="bold")


ax[0].spines['left'].set_color('black')
ax[0].spines['left'].set_linewidth(1.5)
ax[0].spines['right'].set_color('black')
ax[0].spines['right'].set_linewidth(1.5)
ax[0].spines['top'].set_color('black')
ax[0].spines['top'].set_linewidth(1.5)
ax[0].spines['bottom'].set_color('black')
ax[0].spines['bottom'].set_linewidth(1.5)

ax[1].spines['left'].set_color('black')
ax[1].spines['left'].set_linewidth(1.5)
ax[1].spines['right'].set_color('black')
ax[1].spines['right'].set_linewidth(1.5)
ax[1].spines['top'].set_color('black')
ax[1].spines['top'].set_linewidth(1.5)
ax[1].spines['bottom'].set_color('black')
ax[1].spines['bottom'].set_linewidth(1.5)

ax[2].spines['left'].set_color('black')
ax[2].spines['left'].set_linewidth(1.5)
ax[2].spines['right'].set_color('black')
ax[2].spines['right'].set_linewidth(1.5)
ax[2].spines['top'].set_color('black')
ax[2].spines['top'].set_linewidth(1.5)
ax[2].spines['bottom'].set_color('black')
ax[2].spines['bottom'].set_linewidth(1.5)

ax[3].spines['left'].set_color('black')
ax[3].spines['left'].set_linewidth(1.5)
ax[3].spines['right'].set_color('black')
ax[3].spines['right'].set_linewidth(1.5)
ax[3].spines['top'].set_color('black')
ax[3].spines['top'].set_linewidth(1.5)
ax[3].spines['bottom'].set_color('black')
ax[3].spines['bottom'].set_linewidth(1.5)


plt.tight_layout()
plt.show()

# %% [markdown]
# - Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.

# %%
plt.figure(figsize=(10,5), facecolor="lightblue")

ax = plt.axes()
ax.set_facecolor("lightgrey")

plt.scatter(x = stock_daily_returns["Date"], y = stock_daily_returns["AAPL"])
plt.scatter(x = stock_daily_returns["Date"], y = stock_daily_returns["JPM"])

ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(1)
ax.spines['right'].set_color('black')
ax.spines['right'].set_linewidth(1)
ax.spines['bottom'].set_color('black')   
ax.spines['bottom'].set_linewidth(1)
ax.spines['top'].set_color('black')
ax.spines['top'].set_linewidth(1)

plt.legend(["APPLE", "JPM"])
plt.tight_layout()
plt.show()

# %% [markdown]
# - Using Seaborn, plot similar scatterplot between Apple and JP Morgan daily returns.

# %%
plt.figure(figsize=(10,5), facecolor="lightblue")

ax = plt.axes()
ax.set_facecolor("lightgrey")

sns.scatterplot(x = stock_daily_returns["Date"], y = stock_daily_returns["AAPL"], color="blue")
sns.scatterplot(x = stock_daily_returns["Date"], y = stock_daily_returns["JPM"], color="black")

ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(1)
ax.spines['right'].set_color('black')
ax.spines['right'].set_linewidth(1)
ax.spines['bottom'].set_color('black')   
ax.spines['bottom'].set_linewidth(1)
ax.spines['top'].set_color('black')
ax.spines['top'].set_linewidth(1)

plt.legend(["APPLE", "JPM"])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5), facecolor="lightblue")

ax = plt.axes()
ax.set_facecolor("lightgrey")

sns.scatterplot(x = stock_daily_returns["JPM"], y = stock_daily_returns["AAPL"], data=stock_daily_returns, hue="JPM", palette="plasma")


ax.spines['left'].set_color('black')
ax.spines['left'].set_linewidth(1)
ax.spines['right'].set_color('black')
ax.spines['right'].set_linewidth(1)
ax.spines['bottom'].set_color('black')   
ax.spines['bottom'].set_linewidth(1)
ax.spines['top'].set_color('black')
ax.spines['top'].set_linewidth(1)

plt.legend(["APPLE", "JPM"])
plt.tight_layout()
plt.show()

# %% [markdown]
# - Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.

# %%
shares = pd.DataFrame(data = {'allocation %':[70, 10, 10, 10]}, index = ['AAPL', 'JPM', 'P&G', 'UAL'])

# %%
allocation = shares["allocation %"]
companies = ['AAPL', 'JPM', 'P&G', 'UAL']

plt.figure(figsize=(15,10), facecolor="lightseagreen")

plt.pie(allocation, labels=companies, 
        autopct='%1.1f%%',
        startangle=90,
        colors=['brown', 'lightgreen', 'purple', 'grey'])

plt.legend(title="Companies")

plt.show()

# %% [markdown]
# - Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and Standard deviation for both stocks on top of the figure. What did you conclude from this graph?

# %%
plt.figure(figsize = (10, 7));
mu_UAL = round(stock_daily_returns['UAL'].mean(), 2) # mean of distribution
sigma_UAL = round(stock_daily_returns['UAL'].std(), 2) # standard deviation of distribution
mu_PG = round(stock_daily_returns['PG'].mean(), 2) # mean of distribution
sigma_PG = round(stock_daily_returns['PG'].std(), 2) # standard deviation of distribution
stock_daily_returns[['PG','UAL']].plot.hist(bins = 60, alpha = 0.7, figsize = (10, 7));
plt.grid();

plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.

# %%
plt.figure(figsize = (10, 8))
cm = stock_daily_returns.corr()
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# Plot a 3D plot showing all daily returns from JPM, AAPL and UAL [External Research is required]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection = '3d')

x = stock_daily_returns['JPM'].tolist()
y = stock_daily_returns['AAPL'].tolist()
z = stock_daily_returns['UAL'].tolist()

ax.scatter(x, y, z, c = 'r', marker = 'o', s = 1000)

ax.set_xlabel('JP Morgan')
ax.set_ylabel('Apple')
ax.set_zlabel('United Airlines')
# Out:
# Text(0.5, 0, 'United Airlines')

# %% [markdown]
# # GREAT JOB!

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Effective Data Visualization Project</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
